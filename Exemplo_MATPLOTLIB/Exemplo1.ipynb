# %%
plt.scatter(x,y)
plt.show()
# This script generates a scatter plot of random data points.

# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_samples=200, n_features=1, noise=30)
import matplotlib.pyplot as plt

# %%
import matplotlib
